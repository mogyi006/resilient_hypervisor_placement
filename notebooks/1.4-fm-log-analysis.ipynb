# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports.
import itertools
import json

# Related third party imports.
import pandas as pd
import numpy as np

# Local application/library specific imports.

# %%
df = pd.read_json("../results/25_italy/2021-10-25-test-long.json")

# %%
df.query("hp_type == 'heuristics' & latency_factor == 0.1")
# Out:
#     acceptable_count  acceptance_ratio  chs_avg  chs_avg_b  chs_avg_p  \
# 0                 15          0.441176        0         62          6
# 1                 11          0.177419        0         78          6
# 2                  5          0.041322        0         90          4
# 3                  1          0.003968        0        103          0
# 4                  0          0.000000        0         -1         -1
# 5                  0          0.000000        0         -1         -1
# 6                  0          0.000000        0         -1         -1
# 7                  0          0.000000        0         -1         -1
# 8                  0          0.000000        0         -1         -1
# 9                  0          0.000000        0         -1         -1
# 10                 0          0.000000        0         -1         -1
#
#     chs_max_b  chs_max_p cp_objective  diameter  h_count  ... hp_runtime  \
# ...
